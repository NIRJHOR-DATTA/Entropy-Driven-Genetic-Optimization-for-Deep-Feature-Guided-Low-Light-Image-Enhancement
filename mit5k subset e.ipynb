# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from deap import base, creator, tools
import random

# ------------------------------
# 1. Setup Pretrained Feature Extractor with PyTorch (GPU)
# ------------------------------
class VGG16FeatureExtractor(nn.Module):
    def __init__(self):
        super(VGG16FeatureExtractor, self).__init__()
        vgg16 = models.vgg16(pretrained=True)
        self.features = vgg16.features
        for param in self.features.parameters():
            param.requires_grad = False
        self.pool = nn.AdaptiveAvgPool2d((7, 7))

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)
        return x.view(x.size(0), -1)

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
feature_extractor = VGG16FeatureExtractor().to(device)
feature_extractor.eval()

# Transformation for feature extractor
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def extract_features_torch(img: np.ndarray) -> np.ndarray:
    """Extract deep features from an RGB image (numpy array [0,1])"""
    input_tensor = transform((img * 255).astype(np.uint8))
    input_tensor = input_tensor.unsqueeze(0).to(device)
    with torch.no_grad():
        feats = feature_extractor(input_tensor)
    return feats.cpu().numpy().flatten()

# ------------------------------
# 2. GPU-based Image Enhancement Operators
# ------------------------------
def enhance_image_gpu(image: np.ndarray, individual: list) -> np.ndarray:
    brightness, contrast, gamma = individual
    img_tensor = torch.tensor(image, dtype=torch.float32, device=device)
    img_bright = torch.clamp(img_tensor + (brightness / 255.0), 0.0, 1.0)
    img_contrast = torch.clamp(contrast * img_bright, 0.0, 1.0)
    img_gamma = torch.clamp(torch.pow(img_contrast, 1.0 / gamma), 0.0, 1.0)
    return img_gamma.cpu().numpy()

# ------------------------------
# 3. Corrected Fitness Evaluation
# ------------------------------
def evaluate_individual(individual, original_img, orig_features):
    enhanced = enhance_image_gpu(original_img, individual)
    img_tensor = torch.tensor(enhanced, dtype=torch.float32, device=device)
    gray = 0.114 * img_tensor[:,:,0] + 0.587 * img_tensor[:,:,1] + 0.299 * img_tensor[:,:,2]
    hist = torch.histc(gray, bins=256, min=0.0, max=1.0)
    prob = hist / torch.sum(hist)
    entropy = -torch.sum(prob * torch.log2(prob + 1e-6)).item()

    # Deep features
    enhanced_rgb = cv2.cvtColor((enhanced * 255).astype(np.uint8), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    feat_enh = extract_features_torch(enhanced_rgb)
    feat_dist = np.linalg.norm(orig_features - feat_enh)

    # Brightness penalty
    mean_b = torch.mean(img_tensor).item()
    penalty = 0.0
    low, up, factor = 0.35, 0.7, 30.0
    if mean_b < low:
        penalty += (low - mean_b) * factor
    elif mean_b > up:
        penalty += (mean_b - up) * factor

    return entropy, feat_dist + penalty

# ------------------------------
# 4. GA Configuration
# ------------------------------
PARAM_BOUNDS = [(-10, 60), (1.0, 2.0), (1.0, 2.0)]
creator.create("FitnessMulti", base.Fitness, weights=(1.0, -1.0))
creator.create("Individual", list, fitness=creator.FitnessMulti)

toolbox = base.Toolbox()
for i, (low, up) in enumerate(PARAM_BOUNDS):
    toolbox.register(f"attr_{i}", random.uniform, low, up)
toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.attr_0, toolbox.attr_1, toolbox.attr_2), n=1)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate_individual)

def bounded_cx(ind1, ind2):
    tools.cxBlend(ind1, ind2, alpha=0.5)
    for i, (low, up) in enumerate(PARAM_BOUNDS):
        ind1[i] = np.clip(ind1[i], low, up)
        ind2[i] = np.clip(ind2[i], low, up)
    return ind1, ind2

def bounded_mut(ind, indpb):
    for i, (low, up) in enumerate(PARAM_BOUNDS):
        if random.random() < indpb:
            ind[i] += random.gauss(0, (up - low) * 0.1)
            ind[i] = np.clip(ind[i], low, up)
    return ind,

toolbox.register("mate", bounded_cx)
toolbox.register("mutate", bounded_mut, indpb=0.4)
toolbox.register("select", tools.selNSGA2)

# ------------------------------
# 5. Local Search
# ------------------------------
def local_search(ind, original_img, orig_features, max_iter=8):
    best = ind[:]
    best_fit = evaluate_individual(best, original_img, orig_features)
    for _ in range(max_iter):
        neigh = [np.clip(p + random.uniform(-0.5, 0.5), lo, hi)
                 for p, (lo, hi) in zip(best, PARAM_BOUNDS)]
        fit_n = evaluate_individual(neigh, original_img, orig_features)
        if (fit_n[0] > best_fit[0]) or (fit_n[0] == best_fit[0] and fit_n[1] < best_fit[1]):
            best, best_fit = neigh, fit_n
    return best

# ------------------------------
# 6. GA Routine Without Display
# ------------------------------
def run_ga(original_img, ngen=35, pop_size=50):
    orig_f = original_img.astype(np.float32) / 255.0
    orig_rgb = cv2.cvtColor((orig_f * 255).astype(np.uint8), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    feats = extract_features_torch(orig_rgb)

    pop = toolbox.population(n=pop_size)
    for ind in pop:
        ind.fitness.values = toolbox.evaluate(ind, orig_f, feats)
    pop = toolbox.select(pop, len(pop))

    for gen in range(ngen):
        offspring = tools.selTournamentDCD(pop, len(pop))
        offspring = [toolbox.clone(i) for i in offspring]
        # Crossover & Mutation
        for i1, i2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.85:
                toolbox.mate(i1, i2)
                del i1.fitness.values, i2.fitness.values
        mut_rate = 0.3 if gen < ngen//2 else 0.2
        for m in offspring:
            if random.random() < mut_rate:
                toolbox.mutate(m)
                del m.fitness.values

        invalid = [i for i in offspring if not i.fitness.valid]
        for i in invalid:
            i.fitness.values = toolbox.evaluate(i, orig_f, feats)
        pop = toolbox.select(pop + offspring, pop_size)

        # Local search on top 20%
        top = tools.selBest(pop, max(1, int(0.2 * pop_size)))
        for ind in top:
            new_p = local_search(ind, orig_f, feats)
            new_fit = evaluate_individual(new_p, orig_f, feats)
            if (new_fit[0] > ind.fitness.values[0]) or \
               (new_fit[0] == ind.fitness.values[0] and new_fit[1] < ind.fitness.values[1]):
                ind[:] = new_p
                ind.fitness.values = new_fit

    best = tools.selBest(pop, 1)[0]
    enhanced = enhance_image_gpu(orig_f, best)
    return enhanced

# ------------------------------
# 7. Batch Processing
# ------------------------------
if __name__ == "__main__":
    input_root = r"D:\mit-5k-subset\e"
    output_root = r"D:\mit-5k-subset\e_enhanced"
    os.makedirs(output_root, exist_ok=True)

    for subdir, _, files in os.walk(input_root):
        rel_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, rel_path)
        os.makedirs(output_subdir, exist_ok=True)

        for fname in files:
            if not fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
                continue
            in_path = os.path.join(subdir, fname)
            img = cv2.imread(in_path)
            if img is None:
                print(f"Warning: unable to read {in_path}")
                continue
            print(f"Enhancing: {in_path}")
            enhanced = run_ga(img, ngen=5, pop_size=60)
            out_img = (enhanced * 255).astype(np.uint8)
            out_path = os.path.join(output_subdir, fname)
            cv2.imwrite(out_path, out_img)
            print(f"Saved enhanced image: {out_path}")
# Out:
# C:\Users\FA007\.conda\envs\new2\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\FA007\.conda\envs\new2\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Enhancing: D:\mit-5k-subset\e\a0034-LSYD4O2202.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0034-LSYD4O2202.jpg
# Enhancing: D:\mit-5k-subset\e\a0035-dgw_048.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0035-dgw_048.jpg
# Enhancing: D:\mit-5k-subset\e\a0291-IMG_0115.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0291-IMG_0115.jpg
# Enhancing: D:\mit-5k-subset\e\a0436-IMG_2583.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0436-IMG_2583.jpg
# Enhancing: D:\mit-5k-subset\e\a0452-IMG_1646.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0452-IMG_1646.jpg
# Enhancing: D:\mit-5k-subset\e\a0463-jmac_DSC2316.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0463-jmac_DSC2316.jpg
# Enhancing: D:\mit-5k-subset\e\a0631-NKIM_MG_6442.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0631-NKIM_MG_6442.jpg
# Enhancing: D:\mit-5k-subset\e\a0648-IMG_5085.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0648-IMG_5085.jpg
# Enhancing: D:\mit-5k-subset\e\a0712-_DSC8911.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0712-_DSC8911.jpg
# Enhancing: D:\mit-5k-subset\e\a0752-20061213_134314__MG_3708.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0752-20061213_134314__MG_3708.jpg
# Enhancing: D:\mit-5k-subset\e\a0767-jn_20070824_0165.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0767-jn_20070824_0165.jpg
# Enhancing: D:\mit-5k-subset\e\a0770-050703_161554__I2E9266.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0770-050703_161554__I2E9266.jpg
# Enhancing: D:\mit-5k-subset\e\a0775-kme_423.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0775-kme_423.jpg
# Enhancing: D:\mit-5k-subset\e\a0811-20051224_165428__MG_0953.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0811-20051224_165428__MG_0953.jpg
# Enhancing: D:\mit-5k-subset\e\a0843-IMG_0009.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0843-IMG_0009.jpg
# Enhancing: D:\mit-5k-subset\e\a0877-_DGW6231.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0877-_DGW6231.jpg
# Enhancing: D:\mit-5k-subset\e\a0944-20061213_132310__MG_3646.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0944-20061213_132310__MG_3646.jpg
# Enhancing: D:\mit-5k-subset\e\a0982-jmac_MG_1105.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a0982-jmac_MG_1105.jpg
# Enhancing: D:\mit-5k-subset\e\a1085-_DSC6188.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1085-_DSC6188.jpg
# Enhancing: D:\mit-5k-subset\e\a1099-IMG_3511.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1099-IMG_3511.jpg
# Enhancing: D:\mit-5k-subset\e\a1125-07-11-25-at-10h33m49s-_MG_6884.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1125-07-11-25-at-10h33m49s-_MG_6884.jpg
# Enhancing: D:\mit-5k-subset\e\a1160-_MG_1159.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1160-_MG_1159.jpg
# Enhancing: D:\mit-5k-subset\e\a1194-IMG_0479.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1194-IMG_0479.jpg
# Enhancing: D:\mit-5k-subset\e\a1219-IMG_3770.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1219-IMG_3770.jpg
# Enhancing: D:\mit-5k-subset\e\a1268-jmac_MG_5989.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1268-jmac_MG_5989.jpg
# Enhancing: D:\mit-5k-subset\e\a1319-IMG_2601.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1319-IMG_2601.jpg
# Enhancing: D:\mit-5k-subset\e\a1352-07-11-04-at-17h58m48s-_MG_4012.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1352-07-11-04-at-17h58m48s-_MG_4012.jpg
# Enhancing: D:\mit-5k-subset\e\a1368-kme_086.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1368-kme_086.jpg
# Enhancing: D:\mit-5k-subset\e\a1439-IMG_0055.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1439-IMG_0055.jpg
# Enhancing: D:\mit-5k-subset\e\a1454-DSC_0028-1.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1454-DSC_0028-1.jpg
# Enhancing: D:\mit-5k-subset\e\a1606-kme_447.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1606-kme_447.jpg
# Enhancing: D:\mit-5k-subset\e\a1624-_DSC0158.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1624-_DSC0158.jpg
# Enhancing: D:\mit-5k-subset\e\a1659-IMG_4181.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1659-IMG_4181.jpg
# Enhancing: D:\mit-5k-subset\e\a1693-IMG_5069.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1693-IMG_5069.jpg
# Enhancing: D:\mit-5k-subset\e\a1701-jmac_DSC3938.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1701-jmac_DSC3938.jpg
# Enhancing: D:\mit-5k-subset\e\a1717-kme_510.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1717-kme_510.jpg
# Enhancing: D:\mit-5k-subset\e\a1741-kme_305.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1741-kme_305.jpg
# Enhancing: D:\mit-5k-subset\e\a1775-dvf_006.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1775-dvf_006.jpg
# Enhancing: D:\mit-5k-subset\e\a1789-jmac_DSC6275.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1789-jmac_DSC6275.jpg
# Enhancing: D:\mit-5k-subset\e\a1806-kme_342.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a1806-kme_342.jpg
# Enhancing: D:\mit-5k-subset\e\a2031-WP_CRW_5715.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2031-WP_CRW_5715.jpg
# Enhancing: D:\mit-5k-subset\e\a2106-20041009_164255__E6B5580.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2106-20041009_164255__E6B5580.jpg
# Enhancing: D:\mit-5k-subset\e\a2215-DSC_0018.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2215-DSC_0018.jpg
# Enhancing: D:\mit-5k-subset\e\a2224-MB_070908_032.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2224-MB_070908_032.jpg
# Enhancing: D:\mit-5k-subset\e\a2236-jn_2007_12_10__BU_CRUISE_004.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2236-jn_2007_12_10__BU_CRUISE_004.jpg
# Enhancing: D:\mit-5k-subset\e\a2314-20080426_111248__MG_9227.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2314-20080426_111248__MG_9227.jpg
# Enhancing: D:\mit-5k-subset\e\a2398-051007_160936__I2E8858.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2398-051007_160936__I2E8858.jpg
# Enhancing: D:\mit-5k-subset\e\a2416-_DGW6256.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2416-_DGW6256.jpg
# Enhancing: D:\mit-5k-subset\e\a2473-kme_303.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2473-kme_303.jpg
# Enhancing: D:\mit-5k-subset\e\a2499-_DSC1385.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2499-_DSC1385.jpg
# Enhancing: D:\mit-5k-subset\e\a2504-kme_370.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2504-kme_370.jpg
# Enhancing: D:\mit-5k-subset\e\a2560-MB_070908_079.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2560-MB_070908_079.jpg
# Enhancing: D:\mit-5k-subset\e\a2713-kme_337.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2713-kme_337.jpg
# Enhancing: D:\mit-5k-subset\e\a2756-kme_506.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2756-kme_506.jpg
# Enhancing: D:\mit-5k-subset\e\a2761-kme_607.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2761-kme_607.jpg
# Enhancing: D:\mit-5k-subset\e\a2773-jmac_MG_4982.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2773-jmac_MG_4982.jpg
# Enhancing: D:\mit-5k-subset\e\a2835-IMG_4968.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2835-IMG_4968.jpg
# Enhancing: D:\mit-5k-subset\e\a2879-IMG_0481.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2879-IMG_0481.jpg
# Enhancing: D:\mit-5k-subset\e\a2881-20070514_162430__MG_7345.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a2881-20070514_162430__MG_7345.jpg
# Enhancing: D:\mit-5k-subset\e\a3134-IMG_4250.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3134-IMG_4250.jpg
# Enhancing: D:\mit-5k-subset\e\a3193-KE_-2155.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3193-KE_-2155.jpg
# Enhancing: D:\mit-5k-subset\e\a3304-IMG_4322.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3304-IMG_4322.jpg
# Enhancing: D:\mit-5k-subset\e\a3311-IMG_4500.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3311-IMG_4500.jpg
# Enhancing: D:\mit-5k-subset\e\a3330-DSC_0048.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3330-DSC_0048.jpg
# Enhancing: D:\mit-5k-subset\e\a3360-IMG_0017.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3360-IMG_0017.jpg
# Enhancing: D:\mit-5k-subset\e\a3384-kme_524.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3384-kme_524.jpg
# Enhancing: D:\mit-5k-subset\e\a3411-_DGW6385.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3411-_DGW6385.jpg
# Enhancing: D:\mit-5k-subset\e\a3590-IMG_0622.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3590-IMG_0622.jpg
# Enhancing: D:\mit-5k-subset\e\a3697-07-11-24-at-16h05m35s-_MG_6729.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3697-07-11-24-at-16h05m35s-_MG_6729.jpg
# Enhancing: D:\mit-5k-subset\e\a3732-_DGW6272.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3732-_DGW6272.jpg
# Enhancing: D:\mit-5k-subset\e\a3739-KE_-0068.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3739-KE_-0068.jpg
# Enhancing: D:\mit-5k-subset\e\a3741-KE_-8337.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3741-KE_-8337.jpg
# Enhancing: D:\mit-5k-subset\e\a3753-dgw_073.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3753-dgw_073.jpg
# Enhancing: D:\mit-5k-subset\e\a3768-IMG_1641.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3768-IMG_1641.jpg
# Enhancing: D:\mit-5k-subset\e\a3790-IMG_5048.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3790-IMG_5048.jpg
# Enhancing: D:\mit-5k-subset\e\a3831-jmac_MG_5861.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3831-jmac_MG_5861.jpg
# Enhancing: D:\mit-5k-subset\e\a3959-dvf_057.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a3959-dvf_057.jpg
# Enhancing: D:\mit-5k-subset\e\a4062-IMG_1820.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4062-IMG_1820.jpg
# Enhancing: D:\mit-5k-subset\e\a4064-07-12-02-at-16h23m18s-_MG_9020.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4064-07-12-02-at-16h23m18s-_MG_9020.jpg
# Enhancing: D:\mit-5k-subset\e\a4074-kme_428.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4074-kme_428.jpg
# Enhancing: D:\mit-5k-subset\e\a4090-IMG_4996.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4090-IMG_4996.jpg
# Enhancing: D:\mit-5k-subset\e\a4128-kme_388.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4128-kme_388.jpg
# Enhancing: D:\mit-5k-subset\e\a4225-Duggan_081109_3031.jpg
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 203
#     201     continue
#     202 print(f"Enhancing: {in_path}")
# --> 203 enhanced = run_ga(img, ngen=5, pop_size=60)
#     204 out_img = (enhanced * 255).astype(np.uint8)
#     205 out_path = os.path.join(output_subdir, fname)
#
# Cell In[1], line 164, in run_ga(original_img, ngen, pop_size)
#     162 invalid = [i for i in offspring if not i.fitness.valid]
#     163 for i in invalid:
# --> 164     i.fitness.values = toolbox.evaluate(i, orig_f, feats)
#     165 pop = toolbox.select(pop + offspring, pop_size)
#     167 # Local search on top 20%
#
# Cell In[1], line 73, in evaluate_individual(individual, original_img, orig_features)
#      70 entropy = -torch.sum(prob * torch.log2(prob + 1e-6)).item()
#      72 # Deep features
# ---> 73 enhanced_rgb = cv2.cvtColor((enhanced * 255).astype(np.uint8), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
#      74 feat_enh = extract_features_torch(enhanced_rgb)
#      75 feat_dist = np.linalg.norm(orig_features - feat_enh)
#
# MemoryError: Unable to allocate 146. MiB for an array with shape (2912, 4368, 3) and data type float32

# %%
#run this cell only if you stop the first cell without completition
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from deap import base, creator, tools
import random

# ------------------------------
# 1. Setup Pretrained Feature Extractor with PyTorch (GPU)
# ------------------------------
class VGG16FeatureExtractor(nn.Module):
    def __init__(self):
        super(VGG16FeatureExtractor, self).__init__()
        vgg16 = models.vgg16(pretrained=True)
        self.features = vgg16.features
        for param in self.features.parameters():
            param.requires_grad = False
        self.pool = nn.AdaptiveAvgPool2d((7, 7))

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)
        return x.view(x.size(0), -1)

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
feature_extractor = VGG16FeatureExtractor().to(device)
feature_extractor.eval()

# Transformation for feature extractor
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def extract_features_torch(img: np.ndarray) -> np.ndarray:
    """Extract deep features from an RGB image (numpy array [0,1])"""
    input_tensor = transform((img * 255).astype(np.uint8))
    input_tensor = input_tensor.unsqueeze(0).to(device)
    with torch.no_grad():
        feats = feature_extractor(input_tensor)
    return feats.cpu().numpy().flatten()

# ------------------------------
# 2. GPU-based Image Enhancement Operators
# ------------------------------
def enhance_image_gpu(image: np.ndarray, individual: list) -> np.ndarray:
    brightness, contrast, gamma = individual
    img_tensor = torch.tensor(image, dtype=torch.float32, device=device)
    img_bright = torch.clamp(img_tensor + (brightness / 255.0), 0.0, 1.0)
    img_contrast = torch.clamp(contrast * img_bright, 0.0, 1.0)
    img_gamma = torch.clamp(torch.pow(img_contrast, 1.0 / gamma), 0.0, 1.0)
    return img_gamma.cpu().numpy()

# ------------------------------
# 3. Corrected Fitness Evaluation
# ------------------------------
def evaluate_individual(individual, original_img, orig_features):
    enhanced = enhance_image_gpu(original_img, individual)
    img_tensor = torch.tensor(enhanced, dtype=torch.float32, device=device)
    gray = 0.114 * img_tensor[:,:,0] + 0.587 * img_tensor[:,:,1] + 0.299 * img_tensor[:,:,2]
    hist = torch.histc(gray, bins=256, min=0.0, max=1.0)
    prob = hist / torch.sum(hist)
    entropy = -torch.sum(prob * torch.log2(prob + 1e-6)).item()

    # Deep features
    enhanced_rgb = cv2.cvtColor((enhanced * 255).astype(np.uint8), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    feat_enh = extract_features_torch(enhanced_rgb)
    feat_dist = np.linalg.norm(orig_features - feat_enh)

    # Brightness penalty
    mean_b = torch.mean(img_tensor).item()
    penalty = 0.0
    low, up, factor = 0.35, 0.7, 30.0
    if mean_b < low:
        penalty += (low - mean_b) * factor
    elif mean_b > up:
        penalty += (mean_b - up) * factor

    return entropy, feat_dist + penalty

# ------------------------------
# 4. GA Configuration
# ------------------------------
PARAM_BOUNDS = [(-10, 60), (1.0, 2.0), (1.0, 2.0)]
creator.create("FitnessMulti", base.Fitness, weights=(1.0, -1.0))
creator.create("Individual", list, fitness=creator.FitnessMulti)

toolbox = base.Toolbox()
for i, (low, up) in enumerate(PARAM_BOUNDS):
    toolbox.register(f"attr_{i}", random.uniform, low, up)
toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.attr_0, toolbox.attr_1, toolbox.attr_2), n=1)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate_individual)

def bounded_cx(ind1, ind2):
    tools.cxBlend(ind1, ind2, alpha=0.5)
    for i, (low, up) in enumerate(PARAM_BOUNDS):
        ind1[i] = np.clip(ind1[i], low, up)
        ind2[i] = np.clip(ind2[i], low, up)
    return ind1, ind2

def bounded_mut(ind, indpb):
    for i, (low, up) in enumerate(PARAM_BOUNDS):
        if random.random() < indpb:
            ind[i] += random.gauss(0, (up - low) * 0.1)
            ind[i] = np.clip(ind[i], low, up)
    return ind,

toolbox.register("mate", bounded_cx)
toolbox.register("mutate", bounded_mut, indpb=0.4)
toolbox.register("select", tools.selNSGA2)

# ------------------------------
# 5. Local Search
# ------------------------------
def local_search(ind, original_img, orig_features, max_iter=8):
    best = ind[:]
    best_fit = evaluate_individual(best, original_img, orig_features)
    for _ in range(max_iter):
        neigh = [np.clip(p + random.uniform(-0.5, 0.5), lo, hi)
                 for p, (lo, hi) in zip(best, PARAM_BOUNDS)]
        fit_n = evaluate_individual(neigh, original_img, orig_features)
        if (fit_n[0] > best_fit[0]) or (fit_n[0] == best_fit[0] and fit_n[1] < best_fit[1]):
            best, best_fit = neigh, fit_n
    return best

# ------------------------------
# 6. GA Routine Without Display
# ------------------------------
def run_ga(original_img, ngen=35, pop_size=50):
    orig_f = original_img.astype(np.float32) / 255.0
    orig_rgb = cv2.cvtColor((orig_f * 255).astype(np.uint8), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    feats = extract_features_torch(orig_rgb)

    pop = toolbox.population(n=pop_size)
    for ind in pop:
        ind.fitness.values = toolbox.evaluate(ind, orig_f, feats)
    pop = toolbox.select(pop, len(pop))

    for gen in range(ngen):
        offspring = tools.selTournamentDCD(pop, len(pop))
        offspring = [toolbox.clone(i) for i in offspring]
        # Crossover & Mutation
        for i1, i2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.85:
                toolbox.mate(i1, i2)
                del i1.fitness.values, i2.fitness.values
        mut_rate = 0.3 if gen < ngen//2 else 0.2
        for m in offspring:
            if random.random() < mut_rate:
                toolbox.mutate(m)
                del m.fitness.values

        invalid = [i for i in offspring if not i.fitness.valid]
        for i in invalid:
            i.fitness.values = toolbox.evaluate(i, orig_f, feats)
        pop = toolbox.select(pop + offspring, pop_size)

        # Local search on top 20%
        top = tools.selBest(pop, max(1, int(0.2 * pop_size)))
        for ind in top:
            new_p = local_search(ind, orig_f, feats)
            new_fit = evaluate_individual(new_p, orig_f, feats)
            if (new_fit[0] > ind.fitness.values[0]) or \
               (new_fit[0] == ind.fitness.values[0] and new_fit[1] < ind.fitness.values[1]):
                ind[:] = new_p
                ind.fitness.values = new_fit

    best = tools.selBest(pop, 1)[0]
    enhanced = enhance_image_gpu(orig_f, best)
    return enhanced

# ------------------------------
# 7. Batch Processing
# ------------------------------
if __name__ == "__main__":
    input_root = r"D:\mit-5k-subset\e"
    output_root = r"D:\mit-5k-subset\e_enhanced"
    os.makedirs(output_root, exist_ok=True)

    for subdir, _, files in os.walk(input_root):
        rel_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, rel_path)
        os.makedirs(output_subdir, exist_ok=True)
        for fname in files:
            if not fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
                continue
            in_path = os.path.join(subdir, fname)
            out_path = os.path.join(output_subdir, fname)

            if os.path.exists(out_path):
                print(f"Skipping (already processed): {out_path}")
                continue

            img = cv2.imread(in_path)
            if img is None:
                 print(f"Warning: unable to read {in_path}")
                 continue

            print(f"Enhancing: {in_path}")
            enhanced = run_ga(img, ngen=5, pop_size=60)
            out_img = (enhanced * 255).astype(np.uint8)
            cv2.imwrite(out_path, out_img)
            print(f"Saved enhanced image: {out_path}")
# Out:
# C:\Users\FA007\.conda\envs\new2\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\FA007\.conda\envs\new2\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0034-LSYD4O2202.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0035-dgw_048.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0291-IMG_0115.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0436-IMG_2583.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0452-IMG_1646.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0463-jmac_DSC2316.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0631-NKIM_MG_6442.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0648-IMG_5085.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0712-_DSC8911.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0752-20061213_134314__MG_3708.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0767-jn_20070824_0165.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0770-050703_161554__I2E9266.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0775-kme_423.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0811-20051224_165428__MG_0953.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0843-IMG_0009.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0877-_DGW6231.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0944-20061213_132310__MG_3646.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a0982-jmac_MG_1105.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1085-_DSC6188.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1099-IMG_3511.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1125-07-11-25-at-10h33m49s-_MG_6884.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1160-_MG_1159.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1194-IMG_0479.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1219-IMG_3770.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1268-jmac_MG_5989.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1319-IMG_2601.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1352-07-11-04-at-17h58m48s-_MG_4012.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1368-kme_086.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1439-IMG_0055.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1454-DSC_0028-1.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1606-kme_447.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1624-_DSC0158.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1659-IMG_4181.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1693-IMG_5069.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1701-jmac_DSC3938.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1717-kme_510.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1741-kme_305.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1775-dvf_006.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1789-jmac_DSC6275.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a1806-kme_342.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2031-WP_CRW_5715.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2106-20041009_164255__E6B5580.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2215-DSC_0018.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2224-MB_070908_032.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2236-jn_2007_12_10__BU_CRUISE_004.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2314-20080426_111248__MG_9227.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2398-051007_160936__I2E8858.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2416-_DGW6256.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2473-kme_303.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2499-_DSC1385.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2504-kme_370.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2560-MB_070908_079.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2713-kme_337.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2756-kme_506.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2761-kme_607.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2773-jmac_MG_4982.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2835-IMG_4968.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2879-IMG_0481.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a2881-20070514_162430__MG_7345.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3134-IMG_4250.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3193-KE_-2155.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3304-IMG_4322.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3311-IMG_4500.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3330-DSC_0048.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3360-IMG_0017.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3384-kme_524.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3411-_DGW6385.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3590-IMG_0622.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3697-07-11-24-at-16h05m35s-_MG_6729.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3732-_DGW6272.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3739-KE_-0068.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3741-KE_-8337.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3753-dgw_073.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3768-IMG_1641.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3790-IMG_5048.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3831-jmac_MG_5861.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a3959-dvf_057.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4062-IMG_1820.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4064-07-12-02-at-16h23m18s-_MG_9020.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4074-kme_428.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4090-IMG_4996.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4128-kme_388.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4225-Duggan_081109_3031.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4226-kme_0501.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4336-09-05-17-at-15h52m34s-_MG_9211.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4428-DSC_0031.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4454-DSC_0101.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4465-DSC_0051.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4501-DSC_0354.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4528-Duggan_090209_4971.jpg
# Skipping (already processed): D:\mit-5k-subset\e_enhanced\.\a4557-DSC_0477.jpg
# Enhancing: D:\mit-5k-subset\e\a4573-kme_0734.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4573-kme_0734.jpg
# Enhancing: D:\mit-5k-subset\e\a4635-DSC_0017.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4635-DSC_0017.jpg
# Enhancing: D:\mit-5k-subset\e\a4662-Duggan_080115_4605.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4662-Duggan_080115_4605.jpg
# Enhancing: D:\mit-5k-subset\e\a4673-CRW_0009.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4673-CRW_0009.jpg
# Enhancing: D:\mit-5k-subset\e\a4706-DSC_0066.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4706-DSC_0066.jpg
# Enhancing: D:\mit-5k-subset\e\a4826-Duggan_080821_1199.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4826-Duggan_080821_1199.jpg
# Enhancing: D:\mit-5k-subset\e\a4828-Duggan_050710_1299.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4828-Duggan_050710_1299.jpg
# Enhancing: D:\mit-5k-subset\e\a4891-DSC_0069.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4891-DSC_0069.jpg
# Enhancing: D:\mit-5k-subset\e\a4943-20090327_at_11h17m20__MG_0987.jpg
# Saved enhanced image: D:\mit-5k-subset\e_enhanced\.\a4943-20090327_at_11h17m20__MG_0987.jpg
