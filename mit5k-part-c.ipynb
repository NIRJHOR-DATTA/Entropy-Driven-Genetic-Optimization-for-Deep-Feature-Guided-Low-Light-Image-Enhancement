# %%
#my approch
import os
import cv2
import numpy as np
import pandas as pd
from skimage.metrics import structural_similarity as ssim
from skimage.measure import shannon_entropy

import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
from skimage.measure import shannon_entropy

def compute_metrics(original, enhanced):
    """
    Compute PSNR, SSIM, and Shannon Entropy between the original and enhanced images.
    
    Parameters:
        original (np.array): Original image (BGR, uint8).
        enhanced (np.array): Enhanced image (BGR, uint8).
    
    Returns:
        tuple: (PSNR, SSIM, Entropy)
    """
    # Ensure both images have the same size (resize enhanced if necessary)
    if original.shape != enhanced.shape:
        enhanced = cv2.resize(enhanced, (original.shape[1], original.shape[0]))
    
    # PSNR computation
    psnr_value = cv2.PSNR(original, enhanced)
    
    # Determine an appropriate win_size for SSIM based on the image dimensions.
    h, w = original.shape[:2]
    min_dim = min(h, w)
    
    # If the smallest dimension is less than 3 pixels, SSIM is unreliable.
    if min_dim < 3:
        ssim_value = np.nan
    else:
        # Choose a win_size that is odd and does not exceed min_dim.
        if min_dim < 7:
            win_size = min_dim if (min_dim % 2 == 1) else (min_dim - 1)
        else:
            win_size = 7  # default win_size for larger images
        
        # Compute SSIM using the computed win_size and specifying channel_axis=-1 for color images.
        try:
            ssim_value, _ = ssim(original, enhanced, full=True, channel_axis=-1, win_size=win_size)
        except ValueError as e:
            print(f"Error computing SSIM for image of size ({h}, {w}) with win_size={win_size}: {e}")
            ssim_value = np.nan

    # Compute Shannon entropy on the enhanced image.
    # Convert the enhanced image to grayscale.
    enhanced_gray = cv2.cvtColor(enhanced, cv2.COLOR_BGR2GRAY)
    entropy_value = shannon_entropy(enhanced_gray)
    
    return psnr_value, ssim_value, entropy_value



def process_folders(original_folder, enhanced_folder, output_csv=r"D:\mit-5k-subset\my_enhancement_metrics_partc.csv"):
    valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')
    results = []

    for filename in os.listdir(original_folder):
        if filename.lower().endswith(valid_extensions):
            orig_path = os.path.join(original_folder, filename)

            # Remove 'normal' prefix and add 'low' prefix
            basename = filename.replace('normal', 'low', 1)  # replace only the first occurrence
            enh_path = os.path.join(enhanced_folder, basename)

            if not os.path.exists(enh_path):
                print(f"Enhanced image for {filename} not found (expected {basename}). Skipping.")
                continue

            original_img = cv2.imread(orig_path)
            enhanced_img = cv2.imread(enh_path)

            if original_img is None or enhanced_img is None:
                print(f"Error reading {filename}. Skipping.")
                continue

            psnr_val, ssim_val, entropy_val = compute_metrics(original_img, enhanced_img)
            results.append({
                'Filename': filename,  # you can also use a common name like basename if you prefer
                'My PSNR': psnr_val,
                'My SSIM': ssim_val,
                'My Entropy': entropy_val
            })
            print(f"Processed {filename}: PSNR={psnr_val:.2f}, SSIM={ssim_val:.3f}, Entropy={entropy_val:.2f}")

    df = pd.DataFrame(results)
    df.to_csv(output_csv, index=False)
    print(f"Results saved to {output_csv}")
    return df




    # Replace these with the paths to your folders.
original_folder = r"D:\mit-5k-subset\raw"
enhanced_folder = r"D:\mit-5k-subset\c_enhanced"
    
    # Process the folders and save metrics to a CSV.
metrics_df1 = process_folders(original_folder, enhanced_folder)
# Out:
# Processed a0034-LSYD4O2202.jpg: PSNR=11.29, SSIM=0.261, Entropy=7.82
# Processed a0035-dgw_048.jpg: PSNR=13.86, SSIM=0.510, Entropy=7.46
# Processed a0291-IMG_0115.jpg: PSNR=13.10, SSIM=0.267, Entropy=7.95
# Processed a0436-IMG_2583.jpg: PSNR=15.29, SSIM=0.704, Entropy=7.88
# Processed a0452-IMG_1646.jpg: PSNR=25.20, SSIM=0.739, Entropy=6.71
# Processed a0463-jmac_DSC2316.jpg: PSNR=15.70, SSIM=0.509, Entropy=7.28
# Processed a0631-NKIM_MG_6442.jpg: PSNR=24.57, SSIM=0.705, Entropy=7.40
# Processed a0648-IMG_5085.jpg: PSNR=16.23, SSIM=0.606, Entropy=7.83
# Processed a0712-_DSC8911.jpg: PSNR=15.73, SSIM=0.722, Entropy=7.67
# Processed a0752-20061213_134314__MG_3708.jpg: PSNR=17.98, SSIM=0.501, Entropy=7.30
# Processed a0767-jn_20070824_0165.jpg: PSNR=13.94, SSIM=0.278, Entropy=7.76
# Processed a0770-050703_161554__I2E9266.jpg: PSNR=21.13, SSIM=0.645, Entropy=7.73
# Processed a0775-kme_423.jpg: PSNR=12.36, SSIM=0.416, Entropy=7.80
# Processed a0811-20051224_165428__MG_0953.jpg: PSNR=22.72, SSIM=0.884, Entropy=7.51
# Processed a0843-IMG_0009.jpg: PSNR=12.06, SSIM=0.333, Entropy=7.77
# Processed a0877-_DGW6231.jpg: PSNR=17.55, SSIM=0.776, Entropy=7.89
# Processed a0944-20061213_132310__MG_3646.jpg: PSNR=19.29, SSIM=0.494, Entropy=7.67
# Processed a0982-jmac_MG_1105.jpg: PSNR=9.58, SSIM=0.355, Entropy=7.67
# Processed a1085-_DSC6188.jpg: PSNR=13.80, SSIM=0.659, Entropy=7.82
# Processed a1099-IMG_3511.jpg: PSNR=18.78, SSIM=0.636, Entropy=7.70
# Processed a1125-07-11-25-at-10h33m49s-_MG_6884.jpg: PSNR=13.10, SSIM=0.470, Entropy=7.68
# Processed a1160-_MG_1159.jpg: PSNR=12.59, SSIM=0.123, Entropy=7.68
# Processed a1194-IMG_0479.jpg: PSNR=17.19, SSIM=0.719, Entropy=7.87
# Processed a1219-IMG_3770.jpg: PSNR=12.75, SSIM=0.567, Entropy=7.70
# Processed a1268-jmac_MG_5989.jpg: PSNR=13.72, SSIM=0.733, Entropy=7.66
# Processed a1319-IMG_2601.jpg: PSNR=13.73, SSIM=0.549, Entropy=7.96
# Processed a1352-07-11-04-at-17h58m48s-_MG_4012.jpg: PSNR=10.94, SSIM=0.408, Entropy=7.76
# Processed a1368-kme_086.jpg: PSNR=12.74, SSIM=0.760, Entropy=7.54
# Processed a1439-IMG_0055.jpg: PSNR=14.00, SSIM=0.612, Entropy=7.90
# Processed a1454-DSC_0028-1.jpg: PSNR=11.16, SSIM=0.125, Entropy=7.35
# Processed a1606-kme_447.jpg: PSNR=13.45, SSIM=0.158, Entropy=7.89
# Processed a1624-_DSC0158.jpg: PSNR=14.23, SSIM=0.225, Entropy=7.73
# Processed a1659-IMG_4181.jpg: PSNR=16.23, SSIM=0.715, Entropy=7.87
# Processed a1693-IMG_5069.jpg: PSNR=14.54, SSIM=0.490, Entropy=7.89
# Processed a1701-jmac_DSC3938.jpg: PSNR=19.74, SSIM=0.439, Entropy=7.83
# Processed a1717-kme_510.jpg: PSNR=16.33, SSIM=0.613, Entropy=7.94
# Processed a1741-kme_305.jpg: PSNR=12.04, SSIM=0.641, Entropy=7.87
# Processed a1775-dvf_006.jpg: PSNR=12.84, SSIM=0.515, Entropy=7.95
# Processed a1789-jmac_DSC6275.jpg: PSNR=16.38, SSIM=0.459, Entropy=7.56
# Processed a1806-kme_342.jpg: PSNR=8.72, SSIM=0.296, Entropy=7.77
# Processed a2031-WP_CRW_5715.jpg: PSNR=9.73, SSIM=0.234, Entropy=7.90
# Processed a2106-20041009_164255__E6B5580.jpg: PSNR=13.93, SSIM=0.274, Entropy=7.62
# Processed a2215-DSC_0018.jpg: PSNR=16.52, SSIM=0.786, Entropy=7.97
# Processed a2224-MB_070908_032.jpg: PSNR=10.56, SSIM=0.558, Entropy=7.87
# Processed a2236-jn_2007_12_10__BU_CRUISE_004.jpg: PSNR=13.34, SSIM=0.497, Entropy=7.83
# Processed a2314-20080426_111248__MG_9227.jpg: PSNR=15.31, SSIM=0.820, Entropy=7.77
# Processed a2398-051007_160936__I2E8858.jpg: PSNR=10.35, SSIM=0.402, Entropy=7.76
# Processed a2416-_DGW6256.jpg: PSNR=14.51, SSIM=0.682, Entropy=7.64
# Processed a2473-kme_303.jpg: PSNR=20.52, SSIM=0.580, Entropy=7.66
# Processed a2499-_DSC1385.jpg: PSNR=13.16, SSIM=0.527, Entropy=7.70
# Processed a2504-kme_370.jpg: PSNR=15.25, SSIM=0.495, Entropy=7.73
# Processed a2560-MB_070908_079.jpg: PSNR=15.60, SSIM=0.501, Entropy=7.71
# Processed a2713-kme_337.jpg: PSNR=12.58, SSIM=0.497, Entropy=7.48
# Processed a2756-kme_506.jpg: PSNR=12.93, SSIM=0.333, Entropy=7.26
# Processed a2761-kme_607.jpg: PSNR=10.97, SSIM=0.788, Entropy=7.04
# Processed a2773-jmac_MG_4982.jpg: PSNR=19.01, SSIM=0.591, Entropy=7.86
# Processed a2835-IMG_4968.jpg: PSNR=16.72, SSIM=0.648, Entropy=7.95
# Processed a2879-IMG_0481.jpg: PSNR=11.07, SSIM=0.644, Entropy=7.91
# Processed a2881-20070514_162430__MG_7345.jpg: PSNR=18.79, SSIM=0.660, Entropy=7.57
# Processed a3134-IMG_4250.jpg: PSNR=11.06, SSIM=0.678, Entropy=7.50
# Processed a3193-KE_-2155.jpg: PSNR=14.68, SSIM=0.217, Entropy=7.79
# Processed a3304-IMG_4322.jpg: PSNR=17.08, SSIM=0.566, Entropy=7.63
# Processed a3311-IMG_4500.jpg: PSNR=11.94, SSIM=0.743, Entropy=7.88
# Processed a3330-DSC_0048.jpg: PSNR=16.94, SSIM=0.719, Entropy=7.56
# Processed a3360-IMG_0017.jpg: PSNR=18.31, SSIM=0.481, Entropy=7.76
# Processed a3384-kme_524.jpg: PSNR=15.52, SSIM=0.535, Entropy=7.68
# Processed a3411-_DGW6385.jpg: PSNR=19.80, SSIM=0.796, Entropy=7.86
# Processed a3590-IMG_0622.jpg: PSNR=15.70, SSIM=0.784, Entropy=7.75
# Processed a3697-07-11-24-at-16h05m35s-_MG_6729.jpg: PSNR=19.53, SSIM=0.629, Entropy=7.71
# Processed a3732-_DGW6272.jpg: PSNR=18.50, SSIM=0.632, Entropy=7.78
# Processed a3739-KE_-0068.jpg: PSNR=14.98, SSIM=0.396, Entropy=7.70
# Processed a3741-KE_-8337.jpg: PSNR=11.14, SSIM=0.592, Entropy=7.49
# Processed a3753-dgw_073.jpg: PSNR=12.21, SSIM=0.476, Entropy=7.71
# Processed a3768-IMG_1641.jpg: PSNR=15.35, SSIM=0.804, Entropy=7.69
# Processed a3790-IMG_5048.jpg: PSNR=12.42, SSIM=0.414, Entropy=7.31
# Processed a3831-jmac_MG_5861.jpg: PSNR=13.38, SSIM=0.268, Entropy=7.93
# Processed a3959-dvf_057.jpg: PSNR=19.66, SSIM=0.802, Entropy=7.66
# Processed a4062-IMG_1820.jpg: PSNR=20.47, SSIM=0.813, Entropy=7.25
# Processed a4064-07-12-02-at-16h23m18s-_MG_9020.jpg: PSNR=12.78, SSIM=0.571, Entropy=7.48
# Processed a4074-kme_428.jpg: PSNR=16.05, SSIM=0.573, Entropy=7.40
# Processed a4090-IMG_4996.jpg: PSNR=20.84, SSIM=0.850, Entropy=7.58
# Processed a4128-kme_388.jpg: PSNR=11.38, SSIM=0.249, Entropy=7.80
# Processed a4225-Duggan_081109_3031.jpg: PSNR=11.64, SSIM=0.376, Entropy=7.84
# Processed a4226-kme_0501.jpg: PSNR=17.46, SSIM=0.706, Entropy=7.83
# Processed a4336-09-05-17-at-15h52m34s-_MG_9211.jpg: PSNR=14.63, SSIM=0.296, Entropy=7.82
# Processed a4428-DSC_0031.jpg: PSNR=11.40, SSIM=0.175, Entropy=7.67
# Processed a4454-DSC_0101.jpg: PSNR=19.89, SSIM=0.433, Entropy=7.12
# Processed a4465-DSC_0051.jpg: PSNR=10.57, SSIM=0.215, Entropy=7.51
# Processed a4501-DSC_0354.jpg: PSNR=12.28, SSIM=0.375, Entropy=7.86
# Processed a4528-Duggan_090209_4971.jpg: PSNR=17.51, SSIM=0.451, Entropy=7.88
# Processed a4557-DSC_0477.jpg: PSNR=16.65, SSIM=0.510, Entropy=7.76
# Processed a4573-kme_0734.jpg: PSNR=17.82, SSIM=0.742, Entropy=7.85
# Processed a4635-DSC_0017.jpg: PSNR=11.78, SSIM=0.703, Entropy=7.77
# Processed a4662-Duggan_080115_4605.jpg: PSNR=11.31, SSIM=0.505, Entropy=7.89
# Processed a4673-CRW_0009.jpg: PSNR=18.61, SSIM=0.578, Entropy=7.63
# Processed a4706-DSC_0066.jpg: PSNR=14.43, SSIM=0.654, Entropy=7.11
# Processed a4826-Duggan_080821_1199.jpg: PSNR=10.83, SSIM=0.315, Entropy=6.91
# Processed a4828-Duggan_050710_1299.jpg: PSNR=19.23, SSIM=0.424, Entropy=7.61
# Processed a4891-DSC_0069.jpg: PSNR=13.28, SSIM=0.499, Entropy=7.87
# Processed a4943-20090327_at_11h17m20__MG_0987.jpg: PSNR=15.00, SSIM=0.849, Entropy=7.79
# Results saved to D:\mit-5k-subset\my_enhancement_metrics_partc.csv

# %%
import matplotlib.pyplot as plt
# Compute Averages
average_values = metrics_df1.mean(numeric_only=True)
print("\nAverage Values of our approach:")
print(average_values)
# Out:
# Average Values of our approach:
# My PSNR       15.014701
# My SSIM        0.535256
# My Entropy     7.679088
# dtype: float64

# %%
#my approch
import os
import cv2
import numpy as np
import pandas as pd
from skimage.metrics import structural_similarity as ssim
from skimage.measure import shannon_entropy

import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
from skimage.measure import shannon_entropy

def compute_metrics(original, enhanced):
    """
    Compute PSNR, SSIM, and Shannon Entropy between the original and enhanced images.
    
    Parameters:
        original (np.array): Original image (BGR, uint8).
        enhanced (np.array): Enhanced image (BGR, uint8).
    
    Returns:
        tuple: (PSNR, SSIM, Entropy)
    """
    # Ensure both images have the same size (resize enhanced if necessary)
    if original.shape != enhanced.shape:
        enhanced = cv2.resize(enhanced, (original.shape[1], original.shape[0]))
    
    # PSNR computation
    psnr_value = cv2.PSNR(original, enhanced)
    
    # Determine an appropriate win_size for SSIM based on the image dimensions.
    h, w = original.shape[:2]
    min_dim = min(h, w)
    
    # If the smallest dimension is less than 3 pixels, SSIM is unreliable.
    if min_dim < 3:
        ssim_value = np.nan
    else:
        # Choose a win_size that is odd and does not exceed min_dim.
        if min_dim < 7:
            win_size = min_dim if (min_dim % 2 == 1) else (min_dim - 1)
        else:
            win_size = 7  # default win_size for larger images
        
        # Compute SSIM using the computed win_size and specifying channel_axis=-1 for color images.
        try:
            ssim_value, _ = ssim(original, enhanced, full=True, channel_axis=-1, win_size=win_size)
        except ValueError as e:
            print(f"Error computing SSIM for image of size ({h}, {w}) with win_size={win_size}: {e}")
            ssim_value = np.nan

    # Compute Shannon entropy on the enhanced image.
    # Convert the enhanced image to grayscale.
    enhanced_gray = cv2.cvtColor(enhanced, cv2.COLOR_BGR2GRAY)
    entropy_value = shannon_entropy(enhanced_gray)
    
    return psnr_value, ssim_value, entropy_value



def process_folders(original_folder, enhanced_folder, output_csv=r"D:\mit-5k-subset\cidnet_enhancement_metrics_partc.csv"):
    valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')
    results = []

    for filename in os.listdir(original_folder):
        if filename.lower().endswith(valid_extensions):
            orig_path = os.path.join(original_folder, filename)

            # Remove 'normal' prefix and add 'low' prefix
            basename = filename.replace('normal', 'low', 1)  # replace only the first occurrence
            enh_path = os.path.join(enhanced_folder, basename)

            if not os.path.exists(enh_path):
                print(f"Enhanced image for {filename} not found (expected {basename}). Skipping.")
                continue

            original_img = cv2.imread(orig_path)
            enhanced_img = cv2.imread(enh_path)

            if original_img is None or enhanced_img is None:
                print(f"Error reading {filename}. Skipping.")
                continue

            psnr_val, ssim_val, entropy_val = compute_metrics(original_img, enhanced_img)
            results.append({
                'Filename': filename,  # you can also use a common name like basename if you prefer
                'CIDNet PSNR': psnr_val,
                'CIDNet SSIM': ssim_val,
                'CIDNet Entropy': entropy_val
            })
            print(f"Processed {filename}: PSNR={psnr_val:.2f}, SSIM={ssim_val:.3f}, Entropy={entropy_val:.2f}")

    df = pd.DataFrame(results)
    df.to_csv(output_csv, index=False)
    print(f"Results saved to {output_csv}")
    return df




    # Replace these with the paths to your folders.
original_folder = r"D:\mit-5k-subset\raw"
enhanced_folder = r"D:\mit-5k-subset\c_enhanced_cidnet"
    
    # Process the folders and save metrics to a CSV.
metrics_df2 = process_folders(original_folder, enhanced_folder)
# Out:
# Processed a0034-LSYD4O2202.jpg: PSNR=7.24, SSIM=0.141, Entropy=7.58
# Processed a0035-dgw_048.jpg: PSNR=12.54, SSIM=0.488, Entropy=7.57
# Processed a0291-IMG_0115.jpg: PSNR=9.71, SSIM=0.234, Entropy=7.80
# Processed a0436-IMG_2583.jpg: PSNR=6.91, SSIM=0.482, Entropy=7.12
# Processed a0452-IMG_1646.jpg: PSNR=9.94, SSIM=0.576, Entropy=6.50
# Processed a0463-jmac_DSC2316.jpg: PSNR=11.61, SSIM=0.471, Entropy=7.19
# Processed a0631-NKIM_MG_6442.jpg: PSNR=10.09, SSIM=0.614, Entropy=5.32
# Processed a0648-IMG_5085.jpg: PSNR=9.23, SSIM=0.486, Entropy=7.32
# Processed a0712-_DSC8911.jpg: PSNR=6.42, SSIM=0.460, Entropy=6.84
# Processed a0752-20061213_134314__MG_3708.jpg: PSNR=11.92, SSIM=0.428, Entropy=6.86
# Processed a0767-jn_20070824_0165.jpg: PSNR=9.52, SSIM=0.236, Entropy=7.84
# Processed a0770-050703_161554__I2E9266.jpg: PSNR=9.09, SSIM=0.612, Entropy=5.65
# Processed a0775-kme_423.jpg: PSNR=6.39, SSIM=0.261, Entropy=7.34
# Processed a0811-20051224_165428__MG_0953.jpg: PSNR=10.91, SSIM=0.817, Entropy=4.83
# Processed a0843-IMG_0009.jpg: PSNR=7.31, SSIM=0.226, Entropy=7.69
# Processed a0877-_DGW6231.jpg: PSNR=9.54, SSIM=0.586, Entropy=7.67
# Processed a0944-20061213_132310__MG_3646.jpg: PSNR=15.26, SSIM=0.458, Entropy=7.70
# Processed a0982-jmac_MG_1105.jpg: PSNR=4.89, SSIM=0.245, Entropy=7.52
# Processed a1085-_DSC6188.jpg: PSNR=6.74, SSIM=0.438, Entropy=7.29
# Processed a1099-IMG_3511.jpg: PSNR=11.47, SSIM=0.589, Entropy=7.60
# Processed a1125-07-11-25-at-10h33m49s-_MG_6884.jpg: PSNR=6.46, SSIM=0.290, Entropy=7.60
# Processed a1160-_MG_1159.jpg: PSNR=8.29, SSIM=0.088, Entropy=7.77
# Processed a1194-IMG_0479.jpg: PSNR=8.22, SSIM=0.546, Entropy=6.94
# Processed a1219-IMG_3770.jpg: PSNR=8.34, SSIM=0.443, Entropy=7.37
# Processed a1268-jmac_MG_5989.jpg: PSNR=5.88, SSIM=0.507, Entropy=6.94
# Processed a1319-IMG_2601.jpg: PSNR=7.22, SSIM=0.410, Entropy=6.99
# Processed a1352-07-11-04-at-17h58m48s-_MG_4012.jpg: PSNR=5.11, SSIM=0.277, Entropy=7.15
# Processed a1368-kme_086.jpg: PSNR=7.79, SSIM=0.653, Entropy=6.66
# Processed a1439-IMG_0055.jpg: PSNR=8.21, SSIM=0.441, Entropy=6.99
# Processed a1454-DSC_0028-1.jpg: PSNR=8.42, SSIM=0.104, Entropy=7.42
# Processed a1606-kme_447.jpg: PSNR=9.54, SSIM=0.164, Entropy=7.28
# Processed a1624-_DSC0158.jpg: PSNR=10.10, SSIM=0.247, Entropy=6.71
# Processed a1659-IMG_4181.jpg: PSNR=12.93, SSIM=0.794, Entropy=7.53
# Processed a1693-IMG_5069.jpg: PSNR=6.79, SSIM=0.297, Entropy=6.47
# Processed a1701-jmac_DSC3938.jpg: PSNR=9.53, SSIM=0.402, Entropy=5.79
# Processed a1717-kme_510.jpg: PSNR=8.25, SSIM=0.455, Entropy=6.64
# Processed a1741-kme_305.jpg: PSNR=7.19, SSIM=0.491, Entropy=7.44
# Processed a1775-dvf_006.jpg: PSNR=7.27, SSIM=0.372, Entropy=6.66
# Processed a1789-jmac_DSC6275.jpg: PSNR=8.66, SSIM=0.305, Entropy=7.37
# Processed a1806-kme_342.jpg: PSNR=6.24, SSIM=0.246, Entropy=7.76
# Processed a2031-WP_CRW_5715.jpg: PSNR=7.50, SSIM=0.171, Entropy=7.47
# Processed a2106-20041009_164255__E6B5580.jpg: PSNR=17.70, SSIM=0.381, Entropy=7.14
# Processed a2215-DSC_0018.jpg: PSNR=8.02, SSIM=0.605, Entropy=6.83
# Processed a2224-MB_070908_032.jpg: PSNR=5.74, SSIM=0.396, Entropy=7.34
# Processed a2236-jn_2007_12_10__BU_CRUISE_004.jpg: PSNR=9.15, SSIM=0.473, Entropy=7.34
# Processed a2314-20080426_111248__MG_9227.jpg: PSNR=8.72, SSIM=0.581, Entropy=7.57
# Processed a2398-051007_160936__I2E8858.jpg: PSNR=7.35, SSIM=0.319, Entropy=7.82
# Processed a2416-_DGW6256.jpg: PSNR=8.16, SSIM=0.548, Entropy=6.96
# Processed a2473-kme_303.jpg: PSNR=9.22, SSIM=0.392, Entropy=7.30
# Processed a2499-_DSC1385.jpg: PSNR=6.40, SSIM=0.361, Entropy=7.09
# Processed a2504-kme_370.jpg: PSNR=9.96, SSIM=0.440, Entropy=7.53
# Processed a2560-MB_070908_079.jpg: PSNR=8.82, SSIM=0.394, Entropy=7.54
# Processed a2713-kme_337.jpg: PSNR=5.83, SSIM=0.304, Entropy=7.41
# Processed a2756-kme_506.jpg: PSNR=4.87, SSIM=0.201, Entropy=6.90
# Processed a2761-kme_607.jpg: PSNR=8.82, SSIM=0.750, Entropy=6.22
# Processed a2773-jmac_MG_4982.jpg: PSNR=8.04, SSIM=0.414, Entropy=6.83
# Processed a2835-IMG_4968.jpg: PSNR=11.92, SSIM=0.656, Entropy=7.44
# Processed a2879-IMG_0481.jpg: PSNR=7.33, SSIM=0.478, Entropy=7.61
# Processed a2881-20070514_162430__MG_7345.jpg: PSNR=14.25, SSIM=0.658, Entropy=7.08
# Processed a3134-IMG_4250.jpg: PSNR=9.64, SSIM=0.623, Entropy=7.44
# Processed a3193-KE_-2155.jpg: PSNR=7.31, SSIM=0.222, Entropy=5.84
# Processed a3304-IMG_4322.jpg: PSNR=8.52, SSIM=0.442, Entropy=7.11
# Processed a3311-IMG_4500.jpg: PSNR=8.60, SSIM=0.667, Entropy=7.58
# Processed a3330-DSC_0048.jpg: PSNR=9.28, SSIM=0.633, Entropy=6.23
# Processed a3360-IMG_0017.jpg: PSNR=8.67, SSIM=0.363, Entropy=7.39
# Processed a3384-kme_524.jpg: PSNR=12.23, SSIM=0.605, Entropy=6.70
# Processed a3411-_DGW6385.jpg: PSNR=8.21, SSIM=0.647, Entropy=6.80
# Processed a3590-IMG_0622.jpg: PSNR=8.73, SSIM=0.583, Entropy=7.68
# Processed a3697-07-11-24-at-16h05m35s-_MG_6729.jpg: PSNR=9.40, SSIM=0.496, Entropy=6.16
# Processed a3732-_DGW6272.jpg: PSNR=13.88, SSIM=0.605, Entropy=7.67
# Processed a3739-KE_-0068.jpg: PSNR=8.95, SSIM=0.410, Entropy=6.21
# Processed a3741-KE_-8337.jpg: PSNR=11.43, SSIM=0.597, Entropy=6.29
# Processed a3753-dgw_073.jpg: PSNR=7.11, SSIM=0.414, Entropy=6.49
# Processed a3768-IMG_1641.jpg: PSNR=8.06, SSIM=0.669, Entropy=5.97
# Processed a3790-IMG_5048.jpg: PSNR=7.85, SSIM=0.320, Entropy=7.16
# Processed a3831-jmac_MG_5861.jpg: PSNR=7.07, SSIM=0.204, Entropy=7.20
# Processed a3959-dvf_057.jpg: PSNR=11.23, SSIM=0.735, Entropy=7.04
# Processed a4062-IMG_1820.jpg: PSNR=10.38, SSIM=0.685, Entropy=6.80
# Processed a4064-07-12-02-at-16h23m18s-_MG_9020.jpg: PSNR=6.71, SSIM=0.473, Entropy=5.46
# Processed a4074-kme_428.jpg: PSNR=7.75, SSIM=0.472, Entropy=5.08
# Processed a4090-IMG_4996.jpg: PSNR=12.80, SSIM=0.830, Entropy=6.87
# Processed a4128-kme_388.jpg: PSNR=6.39, SSIM=0.155, Entropy=7.17
# Processed a4225-Duggan_081109_3031.jpg: PSNR=6.28, SSIM=0.248, Entropy=7.25
# Processed a4226-kme_0501.jpg: PSNR=7.55, SSIM=0.516, Entropy=7.00
# Processed a4336-09-05-17-at-15h52m34s-_MG_9211.jpg: PSNR=8.61, SSIM=0.262, Entropy=6.51
# Processed a4428-DSC_0031.jpg: PSNR=6.81, SSIM=0.099, Entropy=7.67
# Processed a4454-DSC_0101.jpg: PSNR=12.01, SSIM=0.426, Entropy=4.82
# Processed a4465-DSC_0051.jpg: PSNR=6.85, SSIM=0.162, Entropy=7.54
# Processed a4501-DSC_0354.jpg: PSNR=15.75, SSIM=0.484, Entropy=6.65
# Processed a4528-Duggan_090209_4971.jpg: PSNR=9.36, SSIM=0.394, Entropy=5.60
# Processed a4557-DSC_0477.jpg: PSNR=6.83, SSIM=0.362, Entropy=6.14
# Processed a4573-kme_0734.jpg: PSNR=8.28, SSIM=0.537, Entropy=6.37
# Processed a4635-DSC_0017.jpg: PSNR=4.80, SSIM=0.412, Entropy=5.39
# Processed a4662-Duggan_080115_4605.jpg: PSNR=4.52, SSIM=0.315, Entropy=6.55
# Processed a4673-CRW_0009.jpg: PSNR=20.43, SSIM=0.631, Entropy=7.45
# Processed a4706-DSC_0066.jpg: PSNR=6.71, SSIM=0.517, Entropy=6.94
# Processed a4826-Duggan_080821_1199.jpg: PSNR=4.41, SSIM=0.147, Entropy=7.04
# Processed a4828-Duggan_050710_1299.jpg: PSNR=12.87, SSIM=0.456, Entropy=6.75
# Processed a4891-DSC_0069.jpg: PSNR=6.95, SSIM=0.360, Entropy=7.05
# Processed a4943-20090327_at_11h17m20__MG_0987.jpg: PSNR=7.55, SSIM=0.640, Entropy=6.70
# Results saved to D:\mit-5k-subset\cidnet_enhancement_metrics_partc.csv

# %%
import matplotlib.pyplot as plt
# Compute Averages
average_values = metrics_df2.mean(numeric_only=True)
print("\nCIDnet Average Values:")
print(average_values)
# Out:
# CIDnet Average Values:
# CIDNet PSNR       8.817192
# CIDNet SSIM       0.437170
# CIDNet Entropy    6.938910
# dtype: float64

# %%
merged_df = pd.merge(metrics_df1, metrics_df2, on='Filename', how='inner')

# %%
merged_df.head(8)
# Out:
#                  Filename    My PSNR   My SSIM  My Entropy  CIDNet PSNR  \
# 0    a0034-LSYD4O2202.jpg  11.291699  0.261441    7.816263     7.242207
# 1       a0035-dgw_048.jpg  13.858765  0.510065    7.457179    12.540266
# 2      a0291-IMG_0115.jpg  13.096214  0.267438    7.946829     9.705489
# 3      a0436-IMG_2583.jpg  15.286429  0.703533    7.878344     6.913812
# 4      a0452-IMG_1646.jpg  25.196331  0.739054    6.705804     9.936153
# 5  a0463-jmac_DSC2316.jpg  15.697195  0.508981    7.279908    11.612053
# 6  a0631-NKIM_MG_6442.jpg  24.570486  0.704563    7.402055    10.085871
# 7      a0648-IMG_5085.jpg  16.228797  0.605763    7.828958     9.232245
#
#    CIDNet SSIM  CIDNet Entropy
# 0     0.140831        7.583504
# 1     0.487949        7.570275
# 2     0.233776        7.800211
# 3     0.481592        7.119574
# 4     0.575746        6.496844
# 5     0.470577        7.190468
# 6     0.613735        5.321363
# 7     0.485725        7.318592

# %%
merged_df.to_csv("D:\mit-5k-subset\c_enhanced_cidnet/final_partc.csv")
